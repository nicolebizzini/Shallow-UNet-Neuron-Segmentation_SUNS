# %% [markdown]
# # Train SUNS (train_3_test_1) with IOU=0.2 output folder
#
# This notebook runs the demo training script and saves outputs to `output_IOU_02` under the `mouse7_new` dataset, as configured in `suns/config.py`.

# %%
# --- Setup & configuration ---
import os, sys, runpy, pprint

REPO_ROOT = '/gpfs/home/bizzin01/nicole/code/SUNS_nicole'
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

from suns import config as suns_config

ACTIVE = suns_config.ACTIVE_EXP_SET
print('ACTIVE_EXP_SET =', ACTIVE)
print('DATAFOLDER    =', suns_config.DATAFOLDER_SETS[ACTIVE])
print('OUTPUT_FOLDER =', suns_config.OUTPUT_FOLDER[ACTIVE])
print('EXP_IDs       =', suns_config.EXP_ID_SETS[ACTIVE])
# Out:
# ACTIVE_EXP_SET = mouse7_new
# DATAFOLDER    = /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new
# OUTPUT_FOLDER = output_IOU_02
# EXP_IDs       = ['mouse7_773', 'mouse7_774', 'mouse7_775', 'mouse7_776']

# %%
# --- Resolve paths ---
import os
from pathlib import Path

ACTIVE = suns_config.ACTIVE_EXP_SET
DIR_VIDEO = suns_config.DATAFOLDER_SETS[ACTIVE]
DIR_PARENT = os.path.join(DIR_VIDEO, suns_config.OUTPUT_FOLDER[ACTIVE])
DIR_NET_IN = os.path.join(DIR_PARENT, 'network_input')
DIR_WEIGHTS = os.path.join(DIR_PARENT, 'Weights')
DIR_TRAINOUT = os.path.join(DIR_PARENT, 'training output')
DIR_OUTPUT = os.path.join(DIR_PARENT, 'output_masks')
DIR_TEMP = os.path.join(DIR_PARENT, 'temp')

for d in [DIR_NET_IN, DIR_WEIGHTS, DIR_TRAINOUT, DIR_OUTPUT, DIR_TEMP]:
    Path(d).mkdir(parents=True, exist_ok=True)

print('DIR_PARENT :', DIR_PARENT)
print('DIR_OUTPUT :', DIR_OUTPUT)
# Out:
# DIR_PARENT : /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/output_IOU_02
# DIR_OUTPUT : /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/output_IOU_02/output_masks

# %%
# --- Run the training & parameter optimization script ---
# This executes demo/train_3_test_1/demo_train_CNN_params.py as __main__
SCRIPT = f"{REPO_ROOT}/demo/train_3_test_1/demo_train_CNN_params.py"
print('Running:', SCRIPT)
res = runpy.run_path(SCRIPT, run_name='__main__')
print('Finished run.')
# Out:
# Running: /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/train_3_test_1/demo_train_CNN_params.py
# importing config
# {'list_minArea': [5.0, 6.0, 6.0, 7.0, 8.0, 9.0, 10.0, 10.0, 11.0, 12.0, 13.0], 'list_avgArea': [28.0], 'list_thresh_pmap': [110, 120, 130, 140, 150, 160, 170, 180, 190, 200, 210, 220, 230], 'thresh_COM0': 0.798, 'list_thresh_COM': [1.596, 1.995, 2.394, 2.793, 3.192], 'list_thresh_IOU': [0.5], 'thresh_mask': 0.3, 'list_cons': [1, 2, 3, 4, 5, 6, 7]}
# 256 256 1600 -> 256 256 1600
# FFT planning: 0.10793519020080566 s
# Initialization: 0.0007646083831787109 s
# data loading: 164.56064748764038 s
# spatial filtering: 5.111636161804199 s
#     Log time: 1.9081699848175049 s
#     FFT1 time: 1.0247600078582764 s
#     Mask time: 0.0774221420288086 s
#     FFT2 time: 1.0947239398956299 s
#     Exp time: 1.0065600872039795 s
# temporal filtering: 1.2350208759307861 s
# median computation: 3.892864942550659 s
# normalization: 0.09766817092895508 s
# total per frame: 6.461041420698166 ms
# Network_input saving: 0.11522960662841797 s
# [generate_masks] Using sparse GT: /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/GT Masks/FinalMasks_mouse7_773_sparse.mat → n=757
# [generate_masks] network_input: (1595, 256, 256)  rois: (757, 256, 256) (ncells=757, rows=256, cols=256)
# [generate_masks] Trying FISSA with roi_list of length 757; first ROI shape=(256, 256)
# Doing region growing and data extraction....
# FISSA unavailable or ROI format unsupported (setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.); falling back to simple ROI traces.
# Mask creation: 3.5048019886016846 s
# Mask saving: 0.035054683685302734 s
# 256 256 1600 -> 256 256 1600
# FFT planning: 0.1047053337097168 s
# Initialization: 0.0007920265197753906 s
# data loading: 164.50848054885864 s
# spatial filtering: 5.119127511978149 s
#     Log time: 1.911928653717041 s
#     FFT1 time: 1.021594762802124 s
#     Mask time: 0.0770108699798584 s
#     FFT2 time: 1.1014080047607422 s
#     Exp time: 1.0071852207183838 s
# temporal filtering: 1.2346386909484863 s
# median computation: 3.914120674133301 s
# normalization: 0.09830451011657715 s
# total per frame: 6.479185521602631 ms
# Network_input saving: 0.11143207550048828 s
# [generate_masks] Using sparse GT: /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/GT Masks/FinalMasks_mouse7_774_sparse.mat → n=757
# [generate_masks] network_input: (1595, 256, 256)  rois: (757, 256, 256) (ncells=757, rows=256, cols=256)
# [generate_masks] Trying FISSA with roi_list of length 757; first ROI shape=(256, 256)
# Doing region growing and data extraction....
# FISSA unavailable or ROI format unsupported (setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.); falling back to simple ROI traces.
# Mask creation: 3.6442718505859375 s
# Mask saving: 0.035451650619506836 s
# 256 256 1600 -> 256 256 1600
# FFT planning: 0.1073307991027832 s
# Initialization: 0.0008606910705566406 s
# data loading: 162.34028601646423 s
# spatial filtering: 5.104023694992065 s
#     Log time: 1.9104030132293701 s
#     FFT1 time: 1.0175297260284424 s
#     Mask time: 0.07639598846435547 s
#     FFT2 time: 1.0965032577514648 s
#     Exp time: 1.0031917095184326 s
# temporal filtering: 1.2363042831420898 s
# median computation: 3.9404735565185547 s
# normalization: 0.09841156005859375 s
# total per frame: 6.487313657999039 ms
# Network_input saving: 0.11194777488708496 s
# [generate_masks] Using sparse GT: /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/GT Masks/FinalMasks_mouse7_775_sparse.mat → n=757
# [generate_masks] network_input: (1595, 256, 256)  rois: (757, 256, 256) (ncells=757, rows=256, cols=256)
# [generate_masks] Trying FISSA with roi_list of length 757; first ROI shape=(256, 256)
# Doing region growing and data extraction....
# FISSA unavailable or ROI format unsupported (setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.); falling back to simple ROI traces.
# Mask creation: 2.9397547245025635 s
# Mask saving: 0.035539865493774414 s
# 256 256 1600 -> 256 256 1600
# FFT planning: 0.10579323768615723 s
# Initialization: 0.0007770061492919922 s
# data loading: 162.0822319984436 s
# spatial filtering: 5.1085100173950195 s
#     Log time: 1.9131672382354736 s
#     FFT1 time: 1.0172386169433594 s
#     Mask time: 0.07678580284118652 s
#     FFT2 time: 1.0976905822753906 s
#     Exp time: 1.0036277770996094 s
# temporal filtering: 1.2364418506622314 s
# median computation: 3.941415548324585 s
# normalization: 0.0982668399810791 s
# total per frame: 6.490694880485535 ms
# Network_input saving: 0.11038494110107422 s
# [generate_masks] Using sparse GT: /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/GT Masks/FinalMasks_mouse7_776_sparse.mat → n=757
# [generate_masks] network_input: (1595, 256, 256)  rois: (757, 256, 256) (ncells=757, rows=256, cols=256)
# [generate_masks] Trying FISSA with roi_list of length 757; first ROI shape=(256, 256)
# Doing region growing and data extraction....
# FISSA unavailable or ROI format unsupported (setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.); falling back to simple ROI traces.
# Mask creation: 3.0157413482666016 s
# Mask saving: 0.03507852554321289 s
# Loading training images and masks.
# flips = True, rotate = True
# Epoch 1/60
# 111/112 [============================>.] - ETA: 0s - loss: 4.4050 - dice_loss: 0.7564flips = False, rotate = False
#
#
# The average loss for epoch 0 is  4.3889.
# 112/112 [==============================] - 9s 26ms/step - loss: 4.3889 - dice_loss: 0.7553 - val_loss: 2.2617 - val_dice_loss: 0.5980 - lr: 0.0010
# Epoch 2/60
# 112/112 [==============================] - ETA: 0s - loss: 2.3576 - dice_loss: 0.6173
#
# The average loss for epoch 1 is  2.3576.
# 112/112 [==============================] - 3s 24ms/step - loss: 2.3576 - dice_loss: 0.6173 - val_loss: 2.1076 - val_dice_loss: 0.5948 - lr: 0.0010
# Epoch 3/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1758 - dice_loss: 0.5979
#
# The average loss for epoch 2 is  2.1758.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.1758 - dice_loss: 0.5979 - val_loss: 2.0097 - val_dice_loss: 0.5781 - lr: 0.0010
# Epoch 4/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1031 - dice_loss: 0.5904
#
# The average loss for epoch 3 is  2.1031.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.1031 - dice_loss: 0.5904 - val_loss: 1.9865 - val_dice_loss: 0.5831 - lr: 0.0010
# Epoch 5/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0607 - dice_loss: 0.5848
#
# The average loss for epoch 4 is  2.0607.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0607 - dice_loss: 0.5848 - val_loss: 2.0211 - val_dice_loss: 0.5693 - lr: 0.0010
# Epoch 6/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0335 - dice_loss: 0.5804
#
# The average loss for epoch 5 is  2.0335.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0335 - dice_loss: 0.5804 - val_loss: 1.9383 - val_dice_loss: 0.5817 - lr: 0.0010
# Epoch 7/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0124 - dice_loss: 0.5783
#
# The average loss for epoch 6 is  2.0124.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0124 - dice_loss: 0.5783 - val_loss: 1.9494 - val_dice_loss: 0.5621 - lr: 0.0010
# Epoch 8/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9982 - dice_loss: 0.5754
#
# The average loss for epoch 7 is  1.9982.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9982 - dice_loss: 0.5754 - val_loss: 1.9896 - val_dice_loss: 0.5806 - lr: 0.0010
# Epoch 9/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9851 - dice_loss: 0.5737
#
# The average loss for epoch 8 is  1.9851.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9851 - dice_loss: 0.5737 - val_loss: 1.9694 - val_dice_loss: 0.5644 - lr: 0.0010
# Epoch 10/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9776 - dice_loss: 0.5716
#
# The average loss for epoch 9 is  1.9776.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9776 - dice_loss: 0.5716 - val_loss: 1.9482 - val_dice_loss: 0.5652 - lr: 0.0010
# Epoch 11/60
# 111/112 [============================>.] - ETA: 0s - loss: 1.9699 - dice_loss: 0.5700
#
# The average loss for epoch 10 is  1.9684.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9684 - dice_loss: 0.5699 - val_loss: 1.9220 - val_dice_loss: 0.5587 - lr: 0.0010
# Epoch 12/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9601 - dice_loss: 0.5682
#
# The average loss for epoch 11 is  1.9601.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9601 - dice_loss: 0.5682 - val_loss: 1.9737 - val_dice_loss: 0.5714 - lr: 0.0010
# Epoch 13/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9552 - dice_loss: 0.5677
#
# The average loss for epoch 12 is  1.9552.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9552 - dice_loss: 0.5677 - val_loss: 1.9458 - val_dice_loss: 0.5774 - lr: 0.0010
# Epoch 14/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9478 - dice_loss: 0.5668
#
# The average loss for epoch 13 is  1.9478.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9478 - dice_loss: 0.5668 - val_loss: 1.9407 - val_dice_loss: 0.5681 - lr: 0.0010
# Epoch 15/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9434 - dice_loss: 0.5653
#
# The average loss for epoch 14 is  1.9434.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9434 - dice_loss: 0.5653 - val_loss: 1.9109 - val_dice_loss: 0.5568 - lr: 0.0010
# Epoch 16/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9422 - dice_loss: 0.5651
#
# The average loss for epoch 15 is  1.9422.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9422 - dice_loss: 0.5651 - val_loss: 1.9255 - val_dice_loss: 0.5652 - lr: 0.0010
# Epoch 17/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9368 - dice_loss: 0.5645
#
# The average loss for epoch 16 is  1.9368.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9368 - dice_loss: 0.5645 - val_loss: 1.9866 - val_dice_loss: 0.5699 - lr: 0.0010
# Epoch 18/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9341 - dice_loss: 0.5632
#
# The average loss for epoch 17 is  1.9341.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9341 - dice_loss: 0.5632 - val_loss: 1.9494 - val_dice_loss: 0.5630 - lr: 0.0010
# Epoch 19/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9301 - dice_loss: 0.5638
#
# The average loss for epoch 18 is  1.9301.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9301 - dice_loss: 0.5638 - val_loss: 1.8974 - val_dice_loss: 0.5652 - lr: 0.0010
# Epoch 20/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9285 - dice_loss: 0.5625
#
# The average loss for epoch 19 is  1.9285.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9285 - dice_loss: 0.5625 - val_loss: 1.9366 - val_dice_loss: 0.5593 - lr: 0.0010
# Epoch 21/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9269 - dice_loss: 0.5628
#
# The average loss for epoch 20 is  1.9269.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9269 - dice_loss: 0.5628 - val_loss: 1.9509 - val_dice_loss: 0.5566 - lr: 0.0010
# Epoch 22/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9228 - dice_loss: 0.5613
#
# The average loss for epoch 21 is  1.9228.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9228 - dice_loss: 0.5613 - val_loss: 1.9052 - val_dice_loss: 0.5608 - lr: 0.0010
# Epoch 23/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9206 - dice_loss: 0.5616
#
# The average loss for epoch 22 is  1.9206.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9206 - dice_loss: 0.5616 - val_loss: 1.9188 - val_dice_loss: 0.5664 - lr: 0.0010
# Epoch 24/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9191 - dice_loss: 0.5617
#
# The average loss for epoch 23 is  1.9191.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9191 - dice_loss: 0.5617 - val_loss: 1.9337 - val_dice_loss: 0.5625 - lr: 0.0010
# Epoch 25/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9149 - dice_loss: 0.5606
#
# The average loss for epoch 24 is  1.9149.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9149 - dice_loss: 0.5606 - val_loss: 1.9206 - val_dice_loss: 0.5667 - lr: 5.0000e-04
# Epoch 26/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9145 - dice_loss: 0.5611
#
# The average loss for epoch 25 is  1.9145.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9145 - dice_loss: 0.5611 - val_loss: 1.9226 - val_dice_loss: 0.5672 - lr: 5.0000e-04
# Epoch 27/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9134 - dice_loss: 0.5607
#
# The average loss for epoch 26 is  1.9134.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9134 - dice_loss: 0.5607 - val_loss: 1.9218 - val_dice_loss: 0.5700 - lr: 5.0000e-04
# Epoch 28/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9121 - dice_loss: 0.5608
#
# The average loss for epoch 27 is  1.9121.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9121 - dice_loss: 0.5608 - val_loss: 1.9038 - val_dice_loss: 0.5620 - lr: 5.0000e-04
# Epoch 29/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9118 - dice_loss: 0.5604
#
# The average loss for epoch 28 is  1.9118.
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9118 - dice_loss: 0.5604 - val_loss: 1.9068 - val_dice_loss: 0.5649 - lr: 5.0000e-04
# Epoch 30/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9096 - dice_loss: 0.5610
#
# The average loss for epoch 29 is  1.9096.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9096 - dice_loss: 0.5610 - val_loss: 1.9551 - val_dice_loss: 0.5648 - lr: 2.5000e-04
# Epoch 31/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9107 - dice_loss: 0.5606
#
# The average loss for epoch 30 is  1.9107.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9107 - dice_loss: 0.5606 - val_loss: 1.8900 - val_dice_loss: 0.5709 - lr: 2.5000e-04
# Epoch 32/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9091 - dice_loss: 0.5607
#
# The average loss for epoch 31 is  1.9091.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9091 - dice_loss: 0.5607 - val_loss: 1.8915 - val_dice_loss: 0.5712 - lr: 2.5000e-04
# Epoch 33/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9092 - dice_loss: 0.5600
#
# The average loss for epoch 32 is  1.9092.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9092 - dice_loss: 0.5600 - val_loss: 1.8988 - val_dice_loss: 0.5674 - lr: 2.5000e-04
# Epoch 34/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9105 - dice_loss: 0.5601
#
# The average loss for epoch 33 is  1.9105.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9105 - dice_loss: 0.5601 - val_loss: 1.9149 - val_dice_loss: 0.5663 - lr: 2.5000e-04
# Epoch 35/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9083 - dice_loss: 0.5606
#
# The average loss for epoch 34 is  1.9083.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9083 - dice_loss: 0.5606 - val_loss: 1.9239 - val_dice_loss: 0.5597 - lr: 2.5000e-04
# Epoch 36/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9080 - dice_loss: 0.5602
#
# The average loss for epoch 35 is  1.9080.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9080 - dice_loss: 0.5602 - val_loss: 1.8878 - val_dice_loss: 0.5661 - lr: 2.5000e-04
# Epoch 37/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9081 - dice_loss: 0.5602
#
# The average loss for epoch 36 is  1.9081.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9081 - dice_loss: 0.5602 - val_loss: 1.9298 - val_dice_loss: 0.5707 - lr: 2.5000e-04
# Epoch 38/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9069 - dice_loss: 0.5598
#
# The average loss for epoch 37 is  1.9069.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9069 - dice_loss: 0.5598 - val_loss: 1.9371 - val_dice_loss: 0.5620 - lr: 2.5000e-04
# Epoch 39/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9066 - dice_loss: 0.5597
#
# The average loss for epoch 38 is  1.9066.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9066 - dice_loss: 0.5597 - val_loss: 1.9017 - val_dice_loss: 0.5652 - lr: 2.5000e-04
# Epoch 40/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9079 - dice_loss: 0.5605
#
# The average loss for epoch 39 is  1.9079.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9079 - dice_loss: 0.5605 - val_loss: 1.9103 - val_dice_loss: 0.5704 - lr: 2.5000e-04
# Epoch 41/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9062 - dice_loss: 0.5602
#
# The average loss for epoch 40 is  1.9062.
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9062 - dice_loss: 0.5602 - val_loss: 1.9048 - val_dice_loss: 0.5668 - lr: 2.5000e-04
# Epoch 42/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9048 - dice_loss: 0.5596
#
# The average loss for epoch 41 is  1.9048.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9048 - dice_loss: 0.5596 - val_loss: 1.8974 - val_dice_loss: 0.5683 - lr: 1.2500e-04
# Epoch 43/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9056 - dice_loss: 0.5595
#
# The average loss for epoch 42 is  1.9056.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9056 - dice_loss: 0.5595 - val_loss: 1.8952 - val_dice_loss: 0.5667 - lr: 1.2500e-04
# Epoch 44/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9052 - dice_loss: 0.5600
#
# The average loss for epoch 43 is  1.9052.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9052 - dice_loss: 0.5600 - val_loss: 1.9042 - val_dice_loss: 0.5644 - lr: 1.2500e-04
# Epoch 45/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9022 - dice_loss: 0.5598
#
# The average loss for epoch 44 is  1.9022.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9022 - dice_loss: 0.5598 - val_loss: 1.9370 - val_dice_loss: 0.5686 - lr: 1.2500e-04
# Epoch 46/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9033 - dice_loss: 0.5601
#
# The average loss for epoch 45 is  1.9033.
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9033 - dice_loss: 0.5601 - val_loss: 1.9113 - val_dice_loss: 0.5692 - lr: 1.2500e-04
# Epoch 47/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9045 - dice_loss: 0.5598
#
# The average loss for epoch 46 is  1.9045.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9045 - dice_loss: 0.5598 - val_loss: 1.9024 - val_dice_loss: 0.5690 - lr: 6.2500e-05
# Epoch 48/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9031 - dice_loss: 0.5599
#
# The average loss for epoch 47 is  1.9031.
# Restoring model weights from the end of the best epoch: 36.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9031 - dice_loss: 0.5599 - val_loss: 1.9200 - val_dice_loss: 0.5635 - lr: 6.2500e-05
# Epoch 48: early stopping
# Loading training images and masks.
# flips = True, rotate = True
# Epoch 1/60
# 112/112 [==============================] - ETA: 0s - loss: 5.9627 - dice_loss: 0.7799flips = False, rotate = False
#
#
# The average loss for epoch 0 is  5.9627.
# 112/112 [==============================] - 4s 24ms/step - loss: 5.9627 - dice_loss: 0.7799 - val_loss: 2.3700 - val_dice_loss: 0.6165 - lr: 0.0010
# Epoch 2/60
# 112/112 [==============================] - ETA: 0s - loss: 2.5364 - dice_loss: 0.6443
#
# The average loss for epoch 1 is  2.5364.
# 112/112 [==============================] - 3s 24ms/step - loss: 2.5364 - dice_loss: 0.6443 - val_loss: 2.1757 - val_dice_loss: 0.6261 - lr: 0.0010
# Epoch 3/60
# 112/112 [==============================] - ETA: 0s - loss: 2.3183 - dice_loss: 0.6250
#
# The average loss for epoch 2 is  2.3183.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.3183 - dice_loss: 0.6250 - val_loss: 2.1083 - val_dice_loss: 0.6027 - lr: 0.0010
# Epoch 4/60
# 112/112 [==============================] - ETA: 0s - loss: 2.2354 - dice_loss: 0.6118
#
# The average loss for epoch 3 is  2.2354.
# 112/112 [==============================] - 2s 21ms/step - loss: 2.2354 - dice_loss: 0.6118 - val_loss: 2.0717 - val_dice_loss: 0.5931 - lr: 0.0010
# Epoch 5/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1878 - dice_loss: 0.6055
#
# The average loss for epoch 4 is  2.1878.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.1878 - dice_loss: 0.6055 - val_loss: 2.1071 - val_dice_loss: 0.5905 - lr: 0.0010
# Epoch 6/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1562 - dice_loss: 0.6023
#
# The average loss for epoch 5 is  2.1562.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.1562 - dice_loss: 0.6023 - val_loss: 2.0008 - val_dice_loss: 0.5936 - lr: 0.0010
# Epoch 7/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1335 - dice_loss: 0.5997
#
# The average loss for epoch 6 is  2.1335.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.1335 - dice_loss: 0.5997 - val_loss: 1.9960 - val_dice_loss: 0.5964 - lr: 0.0010
# Epoch 8/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1139 - dice_loss: 0.5987
#
# The average loss for epoch 7 is  2.1139.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.1139 - dice_loss: 0.5987 - val_loss: 2.0279 - val_dice_loss: 0.5886 - lr: 0.0010
# Epoch 9/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0965 - dice_loss: 0.5972
#
# The average loss for epoch 8 is  2.0965.
# 112/112 [==============================] - 2s 21ms/step - loss: 2.0965 - dice_loss: 0.5972 - val_loss: 1.9675 - val_dice_loss: 0.5866 - lr: 0.0010
# Epoch 10/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0836 - dice_loss: 0.5964
#
# The average loss for epoch 9 is  2.0836.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0836 - dice_loss: 0.5964 - val_loss: 1.9808 - val_dice_loss: 0.5934 - lr: 0.0010
# Epoch 11/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0738 - dice_loss: 0.5952
#
# The average loss for epoch 10 is  2.0738.
# 112/112 [==============================] - 2s 21ms/step - loss: 2.0738 - dice_loss: 0.5952 - val_loss: 1.9673 - val_dice_loss: 0.5946 - lr: 0.0010
# Epoch 12/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0655 - dice_loss: 0.5953
#
# The average loss for epoch 11 is  2.0655.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0655 - dice_loss: 0.5953 - val_loss: 2.0011 - val_dice_loss: 0.5907 - lr: 0.0010
# Epoch 13/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0558 - dice_loss: 0.5940
#
# The average loss for epoch 12 is  2.0558.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0558 - dice_loss: 0.5940 - val_loss: 1.9868 - val_dice_loss: 0.5966 - lr: 0.0010
# Epoch 14/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0465 - dice_loss: 0.5928
#
# The average loss for epoch 13 is  2.0465.
# 112/112 [==============================] - 2s 22ms/step - loss: 2.0465 - dice_loss: 0.5928 - val_loss: 2.0673 - val_dice_loss: 0.5932 - lr: 0.0010
# Epoch 15/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0411 - dice_loss: 0.5923
#
# The average loss for epoch 14 is  2.0411.
# 112/112 [==============================] - 2s 22ms/step - loss: 2.0411 - dice_loss: 0.5923 - val_loss: 1.9359 - val_dice_loss: 0.5916 - lr: 0.0010
# Epoch 16/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0370 - dice_loss: 0.5919
#
# The average loss for epoch 15 is  2.0370.
# 112/112 [==============================] - 2s 21ms/step - loss: 2.0370 - dice_loss: 0.5919 - val_loss: 1.9594 - val_dice_loss: 0.5803 - lr: 0.0010
# Epoch 17/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0313 - dice_loss: 0.5913
#
# The average loss for epoch 16 is  2.0313.
# 112/112 [==============================] - 2s 22ms/step - loss: 2.0313 - dice_loss: 0.5913 - val_loss: 2.0415 - val_dice_loss: 0.5985 - lr: 0.0010
# Epoch 18/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0260 - dice_loss: 0.5899
#
# The average loss for epoch 17 is  2.0260.
# 112/112 [==============================] - 2s 21ms/step - loss: 2.0260 - dice_loss: 0.5899 - val_loss: 1.9830 - val_dice_loss: 0.5907 - lr: 0.0010
# Epoch 19/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0197 - dice_loss: 0.5863
#
# The average loss for epoch 18 is  2.0197.
# 112/112 [==============================] - 2s 21ms/step - loss: 2.0197 - dice_loss: 0.5863 - val_loss: 1.8983 - val_dice_loss: 0.5911 - lr: 0.0010
# Epoch 20/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0121 - dice_loss: 0.5809
#
# The average loss for epoch 19 is  2.0121.
# 112/112 [==============================] - 2s 22ms/step - loss: 2.0121 - dice_loss: 0.5809 - val_loss: 1.9801 - val_dice_loss: 0.5767 - lr: 0.0010
# Epoch 21/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0055 - dice_loss: 0.5773
#
# The average loss for epoch 20 is  2.0055.
# 112/112 [==============================] - 2s 21ms/step - loss: 2.0055 - dice_loss: 0.5773 - val_loss: 1.9410 - val_dice_loss: 0.5853 - lr: 0.0010
# Epoch 22/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9986 - dice_loss: 0.5756
#
# The average loss for epoch 21 is  1.9986.
# 112/112 [==============================] - 2s 21ms/step - loss: 1.9986 - dice_loss: 0.5756 - val_loss: 1.9818 - val_dice_loss: 0.5707 - lr: 0.0010
# Epoch 23/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9927 - dice_loss: 0.5737
#
# The average loss for epoch 22 is  1.9927.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9927 - dice_loss: 0.5737 - val_loss: 1.9884 - val_dice_loss: 0.5829 - lr: 0.0010
# Epoch 24/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9865 - dice_loss: 0.5738
#
# The average loss for epoch 23 is  1.9865.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 112/112 [==============================] - 2s 21ms/step - loss: 1.9865 - dice_loss: 0.5738 - val_loss: 1.9684 - val_dice_loss: 0.5866 - lr: 0.0010
# Epoch 25/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9811 - dice_loss: 0.5721
#
# The average loss for epoch 24 is  1.9811.
# 112/112 [==============================] - 2s 21ms/step - loss: 1.9811 - dice_loss: 0.5721 - val_loss: 1.9550 - val_dice_loss: 0.5752 - lr: 5.0000e-04
# Epoch 26/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9792 - dice_loss: 0.5711
#
# The average loss for epoch 25 is  1.9792.
# 112/112 [==============================] - 2s 21ms/step - loss: 1.9792 - dice_loss: 0.5711 - val_loss: 1.9441 - val_dice_loss: 0.5810 - lr: 5.0000e-04
# Epoch 27/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9765 - dice_loss: 0.5711
#
# The average loss for epoch 26 is  1.9765.
# 112/112 [==============================] - 2s 21ms/step - loss: 1.9765 - dice_loss: 0.5711 - val_loss: 1.9648 - val_dice_loss: 0.5823 - lr: 5.0000e-04
# Epoch 28/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9727 - dice_loss: 0.5709
#
# The average loss for epoch 27 is  1.9727.
# 112/112 [==============================] - 2s 21ms/step - loss: 1.9727 - dice_loss: 0.5709 - val_loss: 1.9135 - val_dice_loss: 0.5759 - lr: 5.0000e-04
# Epoch 29/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9709 - dice_loss: 0.5700
#
# The average loss for epoch 28 is  1.9709.
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 112/112 [==============================] - 2s 21ms/step - loss: 1.9709 - dice_loss: 0.5700 - val_loss: 1.9092 - val_dice_loss: 0.5805 - lr: 5.0000e-04
# Epoch 30/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9679 - dice_loss: 0.5696
#
# The average loss for epoch 29 is  1.9679.
# 112/112 [==============================] - 2s 21ms/step - loss: 1.9679 - dice_loss: 0.5696 - val_loss: 1.9773 - val_dice_loss: 0.5816 - lr: 2.5000e-04
# Epoch 31/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9660 - dice_loss: 0.5696
#
# The average loss for epoch 30 is  1.9660.
# Restoring model weights from the end of the best epoch: 19.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9660 - dice_loss: 0.5696 - val_loss: 1.9603 - val_dice_loss: 0.5728 - lr: 2.5000e-04
# Epoch 31: early stopping
# Loading training images and masks.
# flips = True, rotate = True
# Epoch 1/60
# 112/112 [==============================] - ETA: 0s - loss: 4.6604 - dice_loss: 0.7707flips = False, rotate = False
#
#
# The average loss for epoch 0 is  4.6604.
# 112/112 [==============================] - 4s 25ms/step - loss: 4.6604 - dice_loss: 0.7707 - val_loss: 2.2857 - val_dice_loss: 0.6357 - lr: 0.0010
# Epoch 2/60
# 112/112 [==============================] - ETA: 0s - loss: 2.5138 - dice_loss: 0.6320
#
# The average loss for epoch 1 is  2.5138.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.5138 - dice_loss: 0.6320 - val_loss: 2.1195 - val_dice_loss: 0.6243 - lr: 0.0010
# Epoch 3/60
# 112/112 [==============================] - ETA: 0s - loss: 2.2623 - dice_loss: 0.6032
#
# The average loss for epoch 2 is  2.2623.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.2623 - dice_loss: 0.6032 - val_loss: 2.0644 - val_dice_loss: 0.6027 - lr: 0.0010
# Epoch 4/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1618 - dice_loss: 0.5905
#
# The average loss for epoch 3 is  2.1618.
# 112/112 [==============================] - 3s 24ms/step - loss: 2.1618 - dice_loss: 0.5905 - val_loss: 2.0163 - val_dice_loss: 0.6015 - lr: 0.0010
# Epoch 5/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1148 - dice_loss: 0.5847
#
# The average loss for epoch 4 is  2.1148.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.1148 - dice_loss: 0.5847 - val_loss: 1.9696 - val_dice_loss: 0.5979 - lr: 0.0010
# Epoch 6/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0845 - dice_loss: 0.5813
#
# The average loss for epoch 5 is  2.0845.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0845 - dice_loss: 0.5813 - val_loss: 1.9011 - val_dice_loss: 0.5887 - lr: 0.0010
# Epoch 7/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0644 - dice_loss: 0.5788
#
# The average loss for epoch 6 is  2.0644.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0644 - dice_loss: 0.5788 - val_loss: 1.8636 - val_dice_loss: 0.5931 - lr: 0.0010
# Epoch 8/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0483 - dice_loss: 0.5767
#
# The average loss for epoch 7 is  2.0483.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0483 - dice_loss: 0.5767 - val_loss: 1.9372 - val_dice_loss: 0.5869 - lr: 0.0010
# Epoch 9/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0341 - dice_loss: 0.5749
#
# The average loss for epoch 8 is  2.0341.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0341 - dice_loss: 0.5749 - val_loss: 1.9308 - val_dice_loss: 0.5869 - lr: 0.0010
# Epoch 10/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0234 - dice_loss: 0.5734
#
# The average loss for epoch 9 is  2.0234.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0234 - dice_loss: 0.5734 - val_loss: 1.9086 - val_dice_loss: 0.5940 - lr: 0.0010
# Epoch 11/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0169 - dice_loss: 0.5727
#
# The average loss for epoch 10 is  2.0169.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0169 - dice_loss: 0.5727 - val_loss: 1.9227 - val_dice_loss: 0.5940 - lr: 0.0010
# Epoch 12/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0082 - dice_loss: 0.5712
#
# The average loss for epoch 11 is  2.0082.
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0082 - dice_loss: 0.5712 - val_loss: 1.9130 - val_dice_loss: 0.5980 - lr: 0.0010
# Epoch 13/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0001 - dice_loss: 0.5703
#
# The average loss for epoch 12 is  2.0001.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0001 - dice_loss: 0.5703 - val_loss: 1.8807 - val_dice_loss: 0.5864 - lr: 5.0000e-04
# Epoch 14/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9987 - dice_loss: 0.5698
#
# The average loss for epoch 13 is  1.9987.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9987 - dice_loss: 0.5698 - val_loss: 1.9068 - val_dice_loss: 0.5905 - lr: 5.0000e-04
# Epoch 15/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9936 - dice_loss: 0.5693
#
# The average loss for epoch 14 is  1.9936.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9936 - dice_loss: 0.5693 - val_loss: 1.9075 - val_dice_loss: 0.5919 - lr: 5.0000e-04
# Epoch 16/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9929 - dice_loss: 0.5698
#
# The average loss for epoch 15 is  1.9929.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9929 - dice_loss: 0.5698 - val_loss: 1.8789 - val_dice_loss: 0.5926 - lr: 5.0000e-04
# Epoch 17/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9913 - dice_loss: 0.5687
#
# The average loss for epoch 16 is  1.9913.
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9913 - dice_loss: 0.5687 - val_loss: 1.9020 - val_dice_loss: 0.5860 - lr: 5.0000e-04
# Epoch 18/60
# 111/112 [============================>.] - ETA: 0s - loss: 1.9861 - dice_loss: 0.5683
#
# The average loss for epoch 17 is  1.9870.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9870 - dice_loss: 0.5682 - val_loss: 1.9464 - val_dice_loss: 0.5908 - lr: 2.5000e-04
# Epoch 19/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9864 - dice_loss: 0.5680
#
# The average loss for epoch 18 is  1.9864.
# Restoring model weights from the end of the best epoch: 7.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9864 - dice_loss: 0.5680 - val_loss: 1.8835 - val_dice_loss: 0.5919 - lr: 2.5000e-04
# Epoch 19: early stopping
# Loading training images and masks.
# flips = True, rotate = True
# Epoch 1/60
# 112/112 [==============================] - ETA: 0s - loss: 4.2001 - dice_loss: 0.7964flips = False, rotate = False
#
#
# The average loss for epoch 0 is  4.2001.
# 112/112 [==============================] - 4s 25ms/step - loss: 4.2001 - dice_loss: 0.7964 - val_loss: 2.3519 - val_dice_loss: 0.6657 - lr: 0.0010
# Epoch 2/60
# 112/112 [==============================] - ETA: 0s - loss: 2.3978 - dice_loss: 0.6432
#
# The average loss for epoch 1 is  2.3978.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.3978 - dice_loss: 0.6432 - val_loss: 2.1239 - val_dice_loss: 0.6091 - lr: 0.0010
# Epoch 3/60
# 112/112 [==============================] - ETA: 0s - loss: 2.2406 - dice_loss: 0.6154
#
# The average loss for epoch 2 is  2.2406.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.2406 - dice_loss: 0.6154 - val_loss: 2.0692 - val_dice_loss: 0.5930 - lr: 0.0010
# Epoch 4/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1806 - dice_loss: 0.6040
#
# The average loss for epoch 3 is  2.1806.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.1806 - dice_loss: 0.6040 - val_loss: 2.0785 - val_dice_loss: 0.6122 - lr: 0.0010
# Epoch 5/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1377 - dice_loss: 0.5965
#
# The average loss for epoch 4 is  2.1377.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.1377 - dice_loss: 0.5965 - val_loss: 1.9968 - val_dice_loss: 0.5913 - lr: 0.0010
# Epoch 6/60
# 112/112 [==============================] - ETA: 0s - loss: 2.1067 - dice_loss: 0.5917
#
# The average loss for epoch 5 is  2.1067.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.1067 - dice_loss: 0.5917 - val_loss: 2.0226 - val_dice_loss: 0.6010 - lr: 0.0010
# Epoch 7/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0805 - dice_loss: 0.5867
#
# The average loss for epoch 6 is  2.0805.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0805 - dice_loss: 0.5867 - val_loss: 1.9913 - val_dice_loss: 0.5856 - lr: 0.0010
# Epoch 8/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0581 - dice_loss: 0.5829
#
# The average loss for epoch 7 is  2.0581.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0581 - dice_loss: 0.5829 - val_loss: 1.9884 - val_dice_loss: 0.5959 - lr: 0.0010
# Epoch 9/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0405 - dice_loss: 0.5796
#
# The average loss for epoch 8 is  2.0405.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0405 - dice_loss: 0.5796 - val_loss: 1.9460 - val_dice_loss: 0.5959 - lr: 0.0010
# Epoch 10/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0268 - dice_loss: 0.5783
#
# The average loss for epoch 9 is  2.0268.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0268 - dice_loss: 0.5783 - val_loss: 1.9532 - val_dice_loss: 0.5973 - lr: 0.0010
# Epoch 11/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0134 - dice_loss: 0.5765
#
# The average loss for epoch 10 is  2.0134.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0134 - dice_loss: 0.5765 - val_loss: 1.9917 - val_dice_loss: 0.5949 - lr: 0.0010
# Epoch 12/60
# 112/112 [==============================] - ETA: 0s - loss: 2.0049 - dice_loss: 0.5756
#
# The average loss for epoch 11 is  2.0049.
# 112/112 [==============================] - 3s 23ms/step - loss: 2.0049 - dice_loss: 0.5756 - val_loss: 1.9492 - val_dice_loss: 0.5901 - lr: 0.0010
# Epoch 13/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9980 - dice_loss: 0.5744
#
# The average loss for epoch 12 is  1.9980.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9980 - dice_loss: 0.5744 - val_loss: 1.9455 - val_dice_loss: 0.5954 - lr: 0.0010
# Epoch 14/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9923 - dice_loss: 0.5736
#
# The average loss for epoch 13 is  1.9923.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9923 - dice_loss: 0.5736 - val_loss: 1.9403 - val_dice_loss: 0.5959 - lr: 0.0010
# Epoch 15/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9880 - dice_loss: 0.5737
#
# The average loss for epoch 14 is  1.9880.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9880 - dice_loss: 0.5737 - val_loss: 1.9157 - val_dice_loss: 0.5871 - lr: 0.0010
# Epoch 16/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9813 - dice_loss: 0.5731
#
# The average loss for epoch 15 is  1.9813.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9813 - dice_loss: 0.5731 - val_loss: 1.9076 - val_dice_loss: 0.5929 - lr: 0.0010
# Epoch 17/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9768 - dice_loss: 0.5719
#
# The average loss for epoch 16 is  1.9768.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9768 - dice_loss: 0.5719 - val_loss: 1.9910 - val_dice_loss: 0.5912 - lr: 0.0010
# Epoch 18/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9732 - dice_loss: 0.5718
#
# The average loss for epoch 17 is  1.9732.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9732 - dice_loss: 0.5718 - val_loss: 1.8788 - val_dice_loss: 0.5987 - lr: 0.0010
# Epoch 19/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9675 - dice_loss: 0.5709
#
# The average loss for epoch 18 is  1.9675.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9675 - dice_loss: 0.5709 - val_loss: 1.9450 - val_dice_loss: 0.5898 - lr: 0.0010
# Epoch 20/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9668 - dice_loss: 0.5699
#
# The average loss for epoch 19 is  1.9668.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9668 - dice_loss: 0.5699 - val_loss: 1.9038 - val_dice_loss: 0.5761 - lr: 0.0010
# Epoch 21/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9613 - dice_loss: 0.5684
#
# The average loss for epoch 20 is  1.9613.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9613 - dice_loss: 0.5684 - val_loss: 1.9280 - val_dice_loss: 0.5925 - lr: 0.0010
# Epoch 22/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9573 - dice_loss: 0.5679
#
# The average loss for epoch 21 is  1.9573.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9573 - dice_loss: 0.5679 - val_loss: 1.9012 - val_dice_loss: 0.5972 - lr: 0.0010
# Epoch 23/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9563 - dice_loss: 0.5675
#
# The average loss for epoch 22 is  1.9563.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9563 - dice_loss: 0.5675 - val_loss: 1.8734 - val_dice_loss: 0.5897 - lr: 0.0010
# Epoch 24/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9536 - dice_loss: 0.5667
#
# The average loss for epoch 23 is  1.9536.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9536 - dice_loss: 0.5667 - val_loss: 1.9447 - val_dice_loss: 0.6055 - lr: 0.0010
# Epoch 25/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9490 - dice_loss: 0.5664
#
# The average loss for epoch 24 is  1.9490.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9490 - dice_loss: 0.5664 - val_loss: 1.8943 - val_dice_loss: 0.5774 - lr: 0.0010
# Epoch 26/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9462 - dice_loss: 0.5658
#
# The average loss for epoch 25 is  1.9462.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9462 - dice_loss: 0.5658 - val_loss: 1.9333 - val_dice_loss: 0.6028 - lr: 0.0010
# Epoch 27/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9441 - dice_loss: 0.5660
#
# The average loss for epoch 26 is  1.9441.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9441 - dice_loss: 0.5660 - val_loss: 1.9322 - val_dice_loss: 0.5880 - lr: 0.0010
# Epoch 28/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9418 - dice_loss: 0.5653
#
# The average loss for epoch 27 is  1.9418.
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9418 - dice_loss: 0.5653 - val_loss: 1.8994 - val_dice_loss: 0.5819 - lr: 0.0010
# Epoch 29/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9394 - dice_loss: 0.5650
#
# The average loss for epoch 28 is  1.9394.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9394 - dice_loss: 0.5650 - val_loss: 1.9092 - val_dice_loss: 0.5860 - lr: 5.0000e-04
# Epoch 30/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9388 - dice_loss: 0.5646
#
# The average loss for epoch 29 is  1.9388.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9388 - dice_loss: 0.5646 - val_loss: 1.9147 - val_dice_loss: 0.5759 - lr: 5.0000e-04
# Epoch 31/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9365 - dice_loss: 0.5645
#
# The average loss for epoch 30 is  1.9365.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9365 - dice_loss: 0.5645 - val_loss: 1.8303 - val_dice_loss: 0.5946 - lr: 5.0000e-04
# Epoch 32/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9382 - dice_loss: 0.5643
#
# The average loss for epoch 31 is  1.9382.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9382 - dice_loss: 0.5643 - val_loss: 1.9364 - val_dice_loss: 0.5834 - lr: 5.0000e-04
# Epoch 33/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9371 - dice_loss: 0.5643
#
# The average loss for epoch 32 is  1.9371.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9371 - dice_loss: 0.5643 - val_loss: 1.8512 - val_dice_loss: 0.5809 - lr: 5.0000e-04
# Epoch 34/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9327 - dice_loss: 0.5637
#
# The average loss for epoch 33 is  1.9327.
# 112/112 [==============================] - 3s 22ms/step - loss: 1.9327 - dice_loss: 0.5637 - val_loss: 1.9377 - val_dice_loss: 0.5902 - lr: 5.0000e-04
# Epoch 35/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9332 - dice_loss: 0.5643
#
# The average loss for epoch 34 is  1.9332.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9332 - dice_loss: 0.5643 - val_loss: 1.8716 - val_dice_loss: 0.5810 - lr: 5.0000e-04
# Epoch 36/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9331 - dice_loss: 0.5638
#
# The average loss for epoch 35 is  1.9331.
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9331 - dice_loss: 0.5638 - val_loss: 1.8797 - val_dice_loss: 0.5828 - lr: 5.0000e-04
# Epoch 37/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9328 - dice_loss: 0.5634
#
# The average loss for epoch 36 is  1.9328.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9328 - dice_loss: 0.5634 - val_loss: 1.8956 - val_dice_loss: 0.5801 - lr: 2.5000e-04
# Epoch 38/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9297 - dice_loss: 0.5633
#
# The average loss for epoch 37 is  1.9297.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9297 - dice_loss: 0.5633 - val_loss: 1.9220 - val_dice_loss: 0.5801 - lr: 2.5000e-04
# Epoch 39/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9298 - dice_loss: 0.5631
#
# The average loss for epoch 38 is  1.9298.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9298 - dice_loss: 0.5631 - val_loss: 1.9188 - val_dice_loss: 0.5779 - lr: 2.5000e-04
# Epoch 40/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9295 - dice_loss: 0.5632
#
# The average loss for epoch 39 is  1.9295.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9295 - dice_loss: 0.5632 - val_loss: 1.8639 - val_dice_loss: 0.5785 - lr: 2.5000e-04
# Epoch 41/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9287 - dice_loss: 0.5630
#
# The average loss for epoch 40 is  1.9287.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9287 - dice_loss: 0.5630 - val_loss: 1.8226 - val_dice_loss: 0.5938 - lr: 2.5000e-04
# Epoch 42/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9287 - dice_loss: 0.5633
#
# The average loss for epoch 41 is  1.9287.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9287 - dice_loss: 0.5633 - val_loss: 1.9230 - val_dice_loss: 0.5805 - lr: 2.5000e-04
# Epoch 43/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9290 - dice_loss: 0.5634
#
# The average loss for epoch 42 is  1.9290.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9290 - dice_loss: 0.5634 - val_loss: 1.8471 - val_dice_loss: 0.5815 - lr: 2.5000e-04
# Epoch 44/60
# 112/112 [==============================] - ETA: 0s - loss: 1.9267 - dice_loss: 0.5628
#
# The average loss for epoch 43 is  1.9267.
# 112/112 [==============================] - 3s 23ms/step - loss: 1.9267 - dice_loss: 0.5628 - val_loss: 1.8718 - val_dice_loss: 0.5846 - lr: 2.5000e-04
# Epoch 45/60
# ...
# Used 626.9730241298676 s, Best F1 is 0.0
# Using minArea=9.0, avgArea=28.0, thresh_pmap=210
# Used 627.0566148757935 s, Best F1 is 0.0
# Using minArea=10.0, avgArea=28.0, thresh_pmap=210
# Used 627.1321287155151 s, Best F1 is 0.0
# Using minArea=10.0, avgArea=28.0, thresh_pmap=210
# Used 627.2086431980133 s, Best F1 is 0.0
# Using minArea=11.0, avgArea=28.0, thresh_pmap=210
# Used 627.286945104599 s, Best F1 is 0.0
# Using minArea=12.0, avgArea=28.0, thresh_pmap=210
# Used 627.3495254516602 s, Best F1 is 0.0
# Using minArea=13.0, avgArea=28.0, thresh_pmap=210
# Used 627.3983972072601 s, Best F1 is 0.0
# Using thresh_pmap=220
# Used 628.3354525566101 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=220
# Used 628.4928200244904 s, Best F1 is 0.0
# Using minArea=6.0, avgArea=28.0, thresh_pmap=220
# Used 628.5862936973572 s, Best F1 is 0.0
# Using minArea=6.0, avgArea=28.0, thresh_pmap=220
# Used 628.6787242889404 s, Best F1 is 0.0
# Using minArea=7.0, avgArea=28.0, thresh_pmap=220
# Used 628.757776260376 s, Best F1 is 0.0
# Using minArea=8.0, avgArea=28.0, thresh_pmap=220
# Used 628.8340458869934 s, Best F1 is 0.0
# Using minArea=9.0, avgArea=28.0, thresh_pmap=220
# Used 628.909679889679 s, Best F1 is 0.0
# Using minArea=10.0, avgArea=28.0, thresh_pmap=220
# Used 628.9726445674896 s, Best F1 is 0.0
# Using minArea=10.0, avgArea=28.0, thresh_pmap=220
# Used 629.0346367359161 s, Best F1 is 0.0
# Using minArea=11.0, avgArea=28.0, thresh_pmap=220
# Used 629.0969233512878 s, Best F1 is 0.0
# Using minArea=12.0, avgArea=28.0, thresh_pmap=220
# Used 629.150298833847 s, Best F1 is 0.0
# Using minArea=13.0, avgArea=28.0, thresh_pmap=220
# Used 629.150598526001 s, Best F1 is 0.0
# Using thresh_pmap=230
# Used 630.08647108078 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=230
# Used 630.2162070274353 s, Best F1 is 0.0
# Using minArea=6.0, avgArea=28.0, thresh_pmap=230
# Used 630.2913436889648 s, Best F1 is 0.0
# Using minArea=6.0, avgArea=28.0, thresh_pmap=230
# Used 630.368036031723 s, Best F1 is 0.0
# Using minArea=7.0, avgArea=28.0, thresh_pmap=230
# Used 630.4222087860107 s, Best F1 is 0.0
# Using minArea=8.0, avgArea=28.0, thresh_pmap=230
# Used 630.4772975444794 s, Best F1 is 0.0
# Using minArea=9.0, avgArea=28.0, thresh_pmap=230
# Used 630.5245409011841 s, Best F1 is 0.0
# Using minArea=10.0, avgArea=28.0, thresh_pmap=230
# Used 630.5248367786407 s, Best F1 is 0.0
# Using minArea=10.0, avgArea=28.0, thresh_pmap=230
# Used 630.5250844955444 s, Best F1 is 0.0
# Using minArea=11.0, avgArea=28.0, thresh_pmap=230
# Used 630.5252974033356 s, Best F1 is 0.0
# Using minArea=12.0, avgArea=28.0, thresh_pmap=230
# Used 630.5255064964294 s, Best F1 is 0.0
# Using minArea=13.0, avgArea=28.0, thresh_pmap=230
# Used 630.525712966919 s, Best F1 is 0.0
# 16/16 [==============================] - 1s 28ms/step
# Average infrence time 0.8607212652607024 ms/frame
# Using thresh_pmap=110
# Used 2.5557944774627686 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=110
# Used 27.56374430656433 s, Best F1 is 0.4397905759162304
# Using minArea=6.0, avgArea=28.0, thresh_pmap=110
# Used 51.57780599594116 s, Best F1 is 0.4466403162055336
# Using minArea=6.0, avgArea=28.0, thresh_pmap=110
# Used 75.93647575378418 s, Best F1 is 0.4466403162055336
# Using minArea=7.0, avgArea=28.0, thresh_pmap=110
# Used 99.4872658252716 s, Best F1 is 0.4516556291390728
# Using minArea=8.0, avgArea=28.0, thresh_pmap=110
# Used 122.7734522819519 s, Best F1 is 0.4513981358189081
# Using minArea=9.0, avgArea=28.0, thresh_pmap=110
# Used 145.17303252220154 s, Best F1 is 0.4622578490313961
# Using minArea=10.0, avgArea=28.0, thresh_pmap=110
# Used 167.25753545761108 s, Best F1 is 0.4607118871725991
# Using minArea=10.0, avgArea=28.0, thresh_pmap=110
# Used 189.2615110874176 s, Best F1 is 0.4607118871725991
# Using minArea=11.0, avgArea=28.0, thresh_pmap=110
# Used 210.82368445396423 s, Best F1 is 0.46514657980456026
# Using minArea=12.0, avgArea=28.0, thresh_pmap=110
# Used 232.22370958328247 s, Best F1 is 0.46587926509186345
# Using minArea=13.0, avgArea=28.0, thresh_pmap=110
# Used 252.92464447021484 s, Best F1 is 0.4713627386438446
# Using thresh_pmap=120
# Used 255.33935165405273 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=120
# Used 277.1250922679901 s, Best F1 is 0.41471571906354515
# Using minArea=6.0, avgArea=28.0, thresh_pmap=120
# Used 298.01883244514465 s, Best F1 is 0.41672285906945383
# Using minArea=6.0, avgArea=28.0, thresh_pmap=120
# Used 319.22997665405273 s, Best F1 is 0.41672285906945383
# Using minArea=7.0, avgArea=28.0, thresh_pmap=120
# Used 339.56143712997437 s, Best F1 is 0.42448979591836733
# Using minArea=8.0, avgArea=28.0, thresh_pmap=120
# Used 359.359493970871 s, Best F1 is 0.4247205785667324
# Using minArea=9.0, avgArea=28.0, thresh_pmap=120
# Used 378.93013739585876 s, Best F1 is 0.4301786896095301
# Using minArea=10.0, avgArea=28.0, thresh_pmap=120
# Used 397.6584401130676 s, Best F1 is 0.4348395546823838
# Using minArea=10.0, avgArea=28.0, thresh_pmap=120
# Used 416.54182529449463 s, Best F1 is 0.4348395546823838
# Using minArea=11.0, avgArea=28.0, thresh_pmap=120
# Used 435.2051787376404 s, Best F1 is 0.4371217215870881
# Using minArea=12.0, avgArea=28.0, thresh_pmap=120
# Used 453.10900807380676 s, Best F1 is 0.4434087882822903
# Using minArea=13.0, avgArea=28.0, thresh_pmap=120
# Used 470.62355637550354 s, Best F1 is 0.4427994616419919
# Using thresh_pmap=130
# Used 472.91021728515625 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=130
# Used 490.97987151145935 s, Best F1 is 0.38482758620689655
# Using minArea=6.0, avgArea=28.0, thresh_pmap=130
# Used 508.673043012619 s, Best F1 is 0.3924581005586592
# Using minArea=6.0, avgArea=28.0, thresh_pmap=130
# Used 526.1012849807739 s, Best F1 is 0.3924581005586592
# Using minArea=7.0, avgArea=28.0, thresh_pmap=130
# Used 542.9656012058258 s, Best F1 is 0.40197461212976027
# Using minArea=8.0, avgArea=28.0, thresh_pmap=130
# Used 559.587976694107 s, Best F1 is 0.40714285714285714
# Using minArea=9.0, avgArea=28.0, thresh_pmap=130
# Used 575.4943385124207 s, Best F1 is 0.41151079136690644
# Using minArea=10.0, avgArea=28.0, thresh_pmap=130
# Used 590.9741084575653 s, Best F1 is 0.40928882438316405
# Using minArea=10.0, avgArea=28.0, thresh_pmap=130
# Used 606.6953790187836 s, Best F1 is 0.40928882438316405
# Using minArea=11.0, avgArea=28.0, thresh_pmap=130
# Used 621.7507061958313 s, Best F1 is 0.4087591240875912
# Using minArea=12.0, avgArea=28.0, thresh_pmap=130
# Used 636.4209389686584 s, Best F1 is 0.41247342310418145
# Using minArea=13.0, avgArea=28.0, thresh_pmap=130
# Used 650.8621497154236 s, Best F1 is 0.4197707736389684
# Using thresh_pmap=140
# Used 652.9734146595001 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=140
# Used 668.1071817874908 s, Best F1 is 0.3418553688823959
# Using minArea=6.0, avgArea=28.0, thresh_pmap=140
# Used 682.2689292430878 s, Best F1 is 0.3476331360946745
# Using minArea=6.0, avgArea=28.0, thresh_pmap=140
# Used 696.4451875686646 s, Best F1 is 0.3476331360946745
# Using minArea=7.0, avgArea=28.0, thresh_pmap=140
# Used 710.0654458999634 s, Best F1 is 0.35
# Using minArea=8.0, avgArea=28.0, thresh_pmap=140
# Used 723.2952272891998 s, Best F1 is 0.3630952380952381
# Using minArea=9.0, avgArea=28.0, thresh_pmap=140
# Used 735.8843014240265 s, Best F1 is 0.3653705062362436
# Using minArea=10.0, avgArea=28.0, thresh_pmap=140
# Used 748.1190893650055 s, Best F1 is 0.3684598378776713
# Using minArea=10.0, avgArea=28.0, thresh_pmap=140
# Used 760.3548295497894 s, Best F1 is 0.3684598378776713
# Using minArea=11.0, avgArea=28.0, thresh_pmap=140
# Used 772.239217042923 s, Best F1 is 0.3645833333333333
# Using minArea=12.0, avgArea=28.0, thresh_pmap=140
# Used 783.8142750263214 s, Best F1 is 0.3696612665684831
# Using minArea=13.0, avgArea=28.0, thresh_pmap=140
# Used 795.0296974182129 s, Best F1 is 0.36810730253353197
# Using thresh_pmap=150
# Used 796.9768135547638 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=150
# Used 808.9600541591644 s, Best F1 is 0.2953451043338684
# Using minArea=6.0, avgArea=28.0, thresh_pmap=150
# Used 820.0519206523895 s, Best F1 is 0.3057722308892356
# Using minArea=6.0, avgArea=28.0, thresh_pmap=150
# Used 831.194340467453 s, Best F1 is 0.3057722308892356
# Using minArea=7.0, avgArea=28.0, thresh_pmap=150
# Used 841.9186959266663 s, Best F1 is 0.3028391167192429
# Using minArea=8.0, avgArea=28.0, thresh_pmap=150
# Used 852.1863913536072 s, Best F1 is 0.30965682362330404
# Using minArea=9.0, avgArea=28.0, thresh_pmap=150
# Used 862.0046033859253 s, Best F1 is 0.31686274509803924
# Using minArea=10.0, avgArea=28.0, thresh_pmap=150
# Used 871.4464340209961 s, Best F1 is 0.3243683781581092
# Using minArea=10.0, avgArea=28.0, thresh_pmap=150
# Used 881.1518130302429 s, Best F1 is 0.3243683781581092
# Using minArea=11.0, avgArea=28.0, thresh_pmap=150
# Used 890.2177464962006 s, Best F1 is 0.3333333333333333
# Using minArea=12.0, avgArea=28.0, thresh_pmap=150
# Used 898.9680557250977 s, Best F1 is 0.33707865168539325
# Using minArea=13.0, avgArea=28.0, thresh_pmap=150
# Used 907.4135060310364 s, Best F1 is 0.3382113821138212
# Using thresh_pmap=160
# Used 909.1918730735779 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=160
# Used 918.4505348205566 s, Best F1 is 0.23609923011120618
# Using minArea=6.0, avgArea=28.0, thresh_pmap=160
# Used 926.9410729408264 s, Best F1 is 0.24749163879598662
# Using minArea=6.0, avgArea=28.0, thresh_pmap=160
# Used 935.4482803344727 s, Best F1 is 0.24749163879598662
# Using minArea=7.0, avgArea=28.0, thresh_pmap=160
# Used 943.4024519920349 s, Best F1 is 0.25549915397631134
# Using minArea=8.0, avgArea=28.0, thresh_pmap=160
# Used 950.9417486190796 s, Best F1 is 0.2527944969905417
# Using minArea=9.0, avgArea=28.0, thresh_pmap=160
# Used 958.2045521736145 s, Best F1 is 0.2613827993254637
# Using minArea=10.0, avgArea=28.0, thresh_pmap=160
# Used 965.4114322662354 s, Best F1 is 0.26131511528608026
# Using minArea=10.0, avgArea=28.0, thresh_pmap=160
# Used 972.3462376594543 s, Best F1 is 0.26131511528608026
# Using minArea=11.0, avgArea=28.0, thresh_pmap=160
# Used 978.9339244365692 s, Best F1 is 0.265625
# Using minArea=12.0, avgArea=28.0, thresh_pmap=160
# Used 985.29869556427 s, Best F1 is 0.27344434706397897
# Using minArea=13.0, avgArea=28.0, thresh_pmap=160
# Used 991.5095088481903 s, Best F1 is 0.27399650959860383
# Using thresh_pmap=170
# Used 993.118549823761 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=170
# Used 999.854430437088 s, Best F1 is 0.1765799256505576
# Using minArea=6.0, avgArea=28.0, thresh_pmap=170
# Used 1005.949342250824 s, Best F1 is 0.18761726078799248
# Using minArea=6.0, avgArea=28.0, thresh_pmap=170
# Used 1012.0640368461609 s, Best F1 is 0.18761726078799248
# Using minArea=7.0, avgArea=28.0, thresh_pmap=170
# Used 1017.5709850788116 s, Best F1 is 0.18521983161833486
# Using minArea=8.0, avgArea=28.0, thresh_pmap=170
# Used 1022.7322010993958 s, Best F1 is 0.19299905392620623
# Using minArea=9.0, avgArea=28.0, thresh_pmap=170
# Used 1027.5719246864319 s, Best F1 is 0.1947565543071161
# Using minArea=10.0, avgArea=28.0, thresh_pmap=170
# Used 1032.151222229004 s, Best F1 is 0.2005623242736645
# Using minArea=10.0, avgArea=28.0, thresh_pmap=170
# Used 1036.6980061531067 s, Best F1 is 0.2005623242736645
# Using minArea=11.0, avgArea=28.0, thresh_pmap=170
# Used 1041.0429251194 s, Best F1 is 0.2064516129032258
# Using minArea=12.0, avgArea=28.0, thresh_pmap=170
# Used 1045.2018370628357 s, Best F1 is 0.20135527589545013
# Using minArea=13.0, avgArea=28.0, thresh_pmap=170
# Used 1049.077930688858 s, Best F1 is 0.20384615384615384
# Using thresh_pmap=180
# Used 1050.4473204612732 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=180
# Used 1054.1746451854706 s, Best F1 is 0.10434782608695652
# Using minArea=6.0, avgArea=28.0, thresh_pmap=180
# Used 1057.4076037406921 s, Best F1 is 0.1116751269035533
# Using minArea=6.0, avgArea=28.0, thresh_pmap=180
# Used 1060.6214246749878 s, Best F1 is 0.1116751269035533
# Using minArea=7.0, avgArea=28.0, thresh_pmap=180
# Used 1063.5186972618103 s, Best F1 is 0.11752786220871327
# Using minArea=8.0, avgArea=28.0, thresh_pmap=180
# Used 1066.100537776947 s, Best F1 is 0.12266112266112267
# Using minArea=9.0, avgArea=28.0, thresh_pmap=180
# Used 1068.4265477657318 s, Best F1 is 0.12114771519659935
# Using minArea=10.0, avgArea=28.0, thresh_pmap=180
# Used 1070.5683524608612 s, Best F1 is 0.12433011789924973
# Using minArea=10.0, avgArea=28.0, thresh_pmap=180
# Used 1072.7052025794983 s, Best F1 is 0.12433011789924973
# Using minArea=11.0, avgArea=28.0, thresh_pmap=180
# Used 1074.662701845169 s, Best F1 is 0.12154696132596686
# Using minArea=12.0, avgArea=28.0, thresh_pmap=180
# Used 1076.4515252113342 s, Best F1 is 0.11659192825112108
# Using minArea=13.0, avgArea=28.0, thresh_pmap=180
# Used 1078.0931296348572 s, Best F1 is 0.11525423728813558
# Using thresh_pmap=190
# Used 1079.1960434913635 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=190
# Used 1080.3388504981995 s, Best F1 is 0.014580801944106924
# Using minArea=6.0, avgArea=28.0, thresh_pmap=190
# Used 1081.22709608078 s, Best F1 is 0.024630541871921187
# Using minArea=6.0, avgArea=28.0, thresh_pmap=190
# Used 1082.121253490448 s, Best F1 is 0.024630541871921187
# Using minArea=7.0, avgArea=28.0, thresh_pmap=190
# Used 1082.850792646408 s, Best F1 is 0.022113022113022112
# Using minArea=8.0, avgArea=28.0, thresh_pmap=190
# Used 1083.4536955356598 s, Best F1 is 0.022388059701492536
# Using minArea=9.0, avgArea=28.0, thresh_pmap=190
# Used 1083.9803218841553 s, Best F1 is 0.020050125313283207
# Using minArea=10.0, avgArea=28.0, thresh_pmap=190
# Used 1084.4436326026917 s, Best F1 is 0.0202020202020202
# Using minArea=10.0, avgArea=28.0, thresh_pmap=190
# Used 1084.8982877731323 s, Best F1 is 0.0202020202020202
# Using minArea=11.0, avgArea=28.0, thresh_pmap=190
# Used 1085.2973737716675 s, Best F1 is 0.01776649746192894
# Using minArea=12.0, avgArea=28.0, thresh_pmap=190
# Used 1085.6603333950043 s, Best F1 is 0.015267175572519083
# Using minArea=13.0, avgArea=28.0, thresh_pmap=190
# Used 1085.9765148162842 s, Best F1 is 0.010230179028132993
# Using thresh_pmap=200
# Used 1086.9172415733337 s
# Using minArea=5.0, avgArea=28.0, thresh_pmap=200
# Used 1087.0314979553223 s, Best F1 is 0.0
# Using minArea=6.0, avgArea=28.0, thresh_pmap=200
# Used 1087.0735807418823 s, Best F1 is 0.0
# Using minArea=6.0, avgArea=28.0, thresh_pmap=200
# Used 1087.1152811050415 s, Best F1 is 0.0
# Using minArea=7.0, avgArea=28.0, thresh_pmap=200
# Used 1087.1156318187714 s, Best F1 is 0.0
# Using minArea=8.0, avgArea=28.0, thresh_pmap=200
# Used 1087.115884065628 s, Best F1 is 0.0
# Using minArea=9.0, avgArea=28.0, thresh_pmap=200
# Used 1087.1161024570465 s, Best F1 is 0.0
# Using minArea=10.0, avgArea=28.0, thresh_pmap=200
# Used 1087.1163296699524 s, Best F1 is 0.0
# Using minArea=10.0, avgArea=28.0, thresh_pmap=200
# Used 1087.1165421009064 s, Best F1 is 0.0
# Using minArea=11.0, avgArea=28.0, thresh_pmap=200
# Used 1087.1167511940002 s, Best F1 is 0.0
# Using minArea=12.0, avgArea=28.0, thresh_pmap=200
# Used 1087.1169602870941 s, Best F1 is 0.0
# Using minArea=13.0, avgArea=28.0, thresh_pmap=200
# Used 1087.1171698570251 s, Best F1 is 0.0
# Using thresh_pmap=210
# Used 1088.055722951889 s
# Using thresh_pmap=220
# Used 1089.0300002098083 s
# Using thresh_pmap=230
# Used 1090.0011367797852 s
# F1_max= [0.0, 0.47878404053198226, 0.4794788273615635, 0.47857613711272246]
# {'minArea': 13.0, 'avgArea': 28.0, 'thresh_pmap': 110, 'thresh_mask': 0.3, 'thresh_COM0': 0.798, 'thresh_COM': 3.192, 'thresh_IOU': 0.5, 'thresh_consume': 0.75, 'cons': 1}
# F1_mean= 0.47751515624979096
# F1_max= [0.4491467576791809, 0.0, 0.4439946018893387, 0.46416382252559724]
# {'minArea': 12.0, 'avgArea': 28.0, 'thresh_pmap': 110, 'thresh_mask': 0.3, 'thresh_COM0': 0.798, 'thresh_COM': 3.192, 'thresh_IOU': 0.5, 'thresh_consume': 0.75, 'cons': 1}
# F1_mean= 0.44999664034650194
# F1_max= [0.47474132684114423, 0.475, 0.0, 0.4713627386438446]
# {'minArea': 13.0, 'avgArea': 28.0, 'thresh_pmap': 110, 'thresh_mask': 0.3, 'thresh_COM0': 0.798, 'thresh_COM': 3.192, 'thresh_IOU': 0.5, 'thresh_consume': 0.75, 'cons': 1}
# F1_mean= 0.4728733437480807
# F1_max= [0.4674634794156707, 0.4828042328042328, 0.4555712270803949, 0.0]
# {'minArea': 13.0, 'avgArea': 28.0, 'thresh_pmap': 110, 'thresh_mask': 0.3, 'thresh_COM0': 0.798, 'thresh_COM': 3.192, 'thresh_IOU': 0.5, 'thresh_consume': 0.75, 'cons': 1}
# F1_mean= 0.4672935384819033
# Finished run.

# %%
# import subprocess, os
# for id in mouse7_773 mouse7_774 mouse7_775 mouse7_776; do
#   python /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/export_output_masks_IOU_02.py --exp_id "$id" --cv 0
# done

# %%
# Export Output_Masks_<exp_id>.mat for all videos using trained model/params
import os, sys, glob, runpy
from pprint import pprint
from suns import config as suns_config

# Discover directories from config
exp_set = suns_config.ACTIVE_EXP_SET
DIR_VIDEO = suns_config.DATAFOLDER_SETS[exp_set]
DIR_PARENT = os.path.join(DIR_VIDEO, suns_config.OUTPUT_FOLDER[exp_set])
DIR_OUTPUT = os.path.join(DIR_PARENT, 'output_masks')
os.makedirs(DIR_OUTPUT, exist_ok=True)

# Choose which CV index to export with (adjust if needed)
CV_INDEX = 0

# Export for each experiment id
list_Exp_ID = suns_config.EXP_ID_SETS[exp_set]
SCRIPT = '/gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/export_output_masks_IOU_02.py'
print('Export script:', SCRIPT)

for exp_id in list_Exp_ID:
    print(f'Exporting masks for {exp_id} (cv={CV_INDEX})...')
    sys.argv = ['export_output_masks_IOU_02.py', '--exp_id', exp_id, '--cv', str(CV_INDEX)]
    runpy.run_path(SCRIPT, run_name='__main__')

# Verify outputs
mask_files = sorted(glob.glob(os.path.join(DIR_OUTPUT, 'Output_Masks_*.mat')))
print(f'Found {len(mask_files)} mask files in {DIR_OUTPUT}')
pprint(mask_files[:10])
# Out:
# importing config
# Export script: /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/export_output_masks_IOU_02.py
# Exporting masks for mouse7_773 (cv=0)...
# 2025-10-31 11:42:23.031273: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Processing mouse7_773 with:
#   model: /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/output_IOU_02/Weights/Model_CV0.h5
#   opt:   /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/output_IOU_02/output_masks/Optimization_Info_0.mat
#   out:   /gpfs/home/bizzin01/nicole/code/SUNS_nicole/demo/mouse7_new/output_IOU_02/output_masks
# 2025-10-31 11:42:54.070752: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14784 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:61:00.0, compute capability: 7.0
# 2025-10-31 11:42:56.072323: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8907
# 2025-10-31 11:42:56.888631: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 1/1 [==============================] - 4s 4s/step - loss: 0.0107 - dice_loss: 0.0102
# Initialization time: 4.709472894668579 s
# 256 256 1600 -> 256 256 1600
# FFT planning: 0.23353028297424316 s
# Initialization: 0.10536003112792969 s
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-40:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 24
#      22     print(f'Exporting masks for {exp_id} (cv={CV_INDEX})...')
#      23     sys.argv = ['export_output_masks_IOU_02.py', '--exp_id', exp_id, '--cv', str(CV_INDEX)]
# ---> 24     runpy.run_path(SCRIPT, run_name='__main__')
#      26 # Verify outputs
#      27 mask_files = sorted(glob.glob(os.path.join(DIR_OUTPUT, 'Output_Masks_*.mat')))
#
# File ~/.conda/envs/tensorflow-2.12/lib/python3.8/runpy.py:265, in run_path(path_name, init_globals, run_name)
#     261 if isinstance(importer, type(None)) or is_NullImporter:
#     262     # Not a valid sys.path entry, so run the code directly
#     263     # execfile() doesn't help as we want to allow compiled files
#     264     code, fname = _get_code_from_file(run_name, path_name)
# --> 265     return _run_module_code(code, init_globals, run_name,
#     266                             pkg_name=pkg_name, script_name=fname)
#     267 else:
#     268     # Finder is defined for path, so add it to
#     269     # the start of sys.path
#     270     sys.path.insert(0, path_name)
#
# File ~/.conda/envs/tensorflow-2.12/lib/python3.8/runpy.py:97, in _run_module_code(code, init_globals, mod_name, mod_spec, pkg_name, script_name)
#      95 with _TempModule(mod_name) as temp_module, _ModifiedArgv0(fname):
#      96     mod_globals = temp_module.module.__dict__
# ---> 97     _run_code(code, mod_globals, init_globals,
#      98               mod_name, mod_spec, pkg_name, script_name)
#      99 # Copy the globals of the temporary module, as they
#     100 # may be cleared when the temporary module goes away
#     101 return mod_globals.copy()
#
# File ~/.conda/envs/tensorflow-2.12/lib/python3.8/runpy.py:87, in _run_code(code, run_globals, init_globals, mod_name, mod_spec, pkg_name, script_name)
#      79         pkg_name = mod_spec.parent
#      80 run_globals.update(__name__ = mod_name,
#      81                    __file__ = fname,
#      82                    __cached__ = cached,
#    (...)
#      85                    __package__ = pkg_name,
#      86                    __spec__ = mod_spec)
# ---> 87 exec(code, run_globals)
#      88 return run_globals
#
# File ~/nicole/code/SUNS_nicole/demo/mouse7_new/export_output_masks_IOU_02.py:120
#     116     return 0
#     119 if __name__ == '__main__':
# --> 120     raise SystemExit(main())
#
# File ~/nicole/code/SUNS_nicole/demo/mouse7_new/export_output_masks_IOU_02.py:96, in main()
#      94 # Use multiprocessing to match complete_segment's default useMP=True path
#      95 with mp.Pool() as p:
# ---> 96     Masks, Masks_2, times_active, _, _ = suns_batch(
#      97         dir_video=dir_video,
#      98         Exp_ID=args.exp_id,
#      99         filename_CNN=model_path,
#     100         Params_pre=Params_pre,
#     101         Params_post=Params_post,
#     102         batch_size_eval=1,
#     103         display=True,
#     104         p=p,
#     105     )
#     107 # Save MATLAB file as (Lx, Ly, n)
#     108 Masks_out = Masks.astype(np.uint8).transpose(1, 2, 0)
#
# File /gpfs/data/shohamlab/nicole/code/SUNS_nicole/suns/run_suns.py:114, in suns_batch(dir_video, Exp_ID, filename_CNN, Params_pre, Params_post, batch_size_eval, useSF, useTF, useSNR, med_subtract, useWT, prealloc, display, useMP, p)
#     109     print('Initialization time: {} s'.format(time_init-start))
#     111 # %% Actual processing starts after the video is loaded into memory
#     112     # which is in the middle of "preprocess_video", represented by the output "start"
#     113 # pre-processing including loading data
# --> 114 video_input, start = preprocess_video(dir_video, Exp_ID, Params_pre, \
#     115     useSF=useSF, useTF=useTF, useSNR=useSNR, med_subtract=med_subtract, prealloc=prealloc, display=display)
#     116 if display:
#     117     end_pre = time.time()
#
# File /gpfs/data/shohamlab/nicole/code/SUNS_nicole/suns/PreProcessing/preprocessing_functions.py:516, in preprocess_video(dir_video, Exp_ID, Params, dir_network_input, useSF, useTF, useSNR, med_subtract, prealloc, display)
#     514 for t in range(nframes): # use this one to save memory
#     515     try:
# --> 516         bb[t, :rows, :cols] = np.clip(np.array(h5_file[dset][t]), 0, None)
#     517     except OSError as e:
#     518         # Handle compressed chunk read failures by repeating the previous frame (or zeros for t==0)
#     519         if t > 0:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/.conda/envs/tensorflow-2.12/lib/python3.8/site-packages/h5py/_hl/dataset.py:758, in Dataset.__getitem__(self, args, new_dtype)
#     756 if self._fast_read_ok and (new_dtype is None):
#     757     try:
# --> 758         return self._fast_reader.read(args)
#     759     except TypeError:
#     760         pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:
